# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# Bước 1: Tạo DataFrame mẫu (bạn thay bằng file của bạn)
df = pd.DataFrame({
    "id": [1, 2, 3],
    "name": ["Alice", "Bob", "Charlie"],
    "score": [85.0, 92.5, 78.0]
})

# Bước 2: Thông tin kết nối BigQuery
project_id = "fsds-bi"
dataset_id = "sample_datawarehouse"
table_id = "fake_data"
key_path = "/Users/nguyentienhuy/Documents/fsds/BI/material/Lesson 15 - Python 3/fsds-bi-96a792b2baf8.json"

# Bước 3: Tạo client BigQuery
credentials = service_account.Credentials.from_service_account_file(key_path)
client = bigquery.Client(credentials=credentials, project=project_id)

# Bước 4: Tạo tham chiếu bảng
table_ref = f"{project_id}.{dataset_id}.{table_id}"

# Bước 5: Cấu hình ghi đè bảng nếu đã tồn tại
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
    autodetect=True,  
)

# Bước 6: Load DataFrame vào BigQuery
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()  

# Bước 7: Xác nhận
print(f"✅ Đã tải {job.output_rows} dòng vào bảng {table_ref}")
# Out:
# ✅ Đã tải 3 dòng vào bảng fsds-bi.sample_datawarehouse.fake_data

# %%
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# Bước 1: Tạo DataFrame mẫu (bạn thay bằng file của bạn)
df = pd.read_csv('/Users/nguyentienhuy/Documents/fsds/BI/datawarehouse/DimCustomer.csv')

# Bước 2: Thông tin kết nối BigQuery
project_id = "fsds-bi"
dataset_id = "sample_datawarehouse"
table_id = "Dim_Customer"
key_path = "/Users/nguyentienhuy/Documents/fsds/BI/material/Lesson 15 - Python 3/fsds-bi-96a792b2baf8.json"

# Bước 3: Tạo client BigQuery
credentials = service_account.Credentials.from_service_account_file(key_path)
client = bigquery.Client(credentials=credentials, project=project_id)

# Bước 4: Tạo tham chiếu bảng
table_ref = f"{project_id}.{dataset_id}.{table_id}"

# Bước 5: Cấu hình ghi đè bảng nếu đã tồn tại
job_config = bigquery.LoadJobConfig(
    write_disposition=bigquery.WriteDisposition.WRITE_TRUNCATE,
    autodetect=True,  
)

# Bước 6: Load DataFrame vào BigQuery
job = client.load_table_from_dataframe(df, table_ref, job_config=job_config)
job.result()  

# Bước 7: Xác nhận
print(f"✅ Đã tải {job.output_rows} dòng vào bảng {table_ref}")
# Out:
# ✅ Đã tải 18484 dòng vào bảng fsds-bi.sample_datawarehouse.Dim_Customer

# %%
import pandas as pd

df = pd.read_csv('/Users/nguyentienhuy/Documents/fsds/BI/datawarehouse/DimCustomer.csv')

df.head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle   BirthDate MaritalStatus  ... EnglishOccupation  \
# 0     Yang          0  06/10/1971             M  ...      Professional
# 1    Huang          0  10/05/1976             S  ...      Professional
# 2   Torres          0  09/02/1971             M  ...      Professional
# 3      Zhu          0  14/08/1973             S  ...      Professional
# 4  Johnson          0  05/08/1979             S  ...      Professional
#
# ...

# %% [markdown]
# # Làm như thế nào load hết các file trong datawarehouse vào Bigquery?

# %%
import os
import pandas as pd
from google.cloud import bigquery
from google.oauth2 import service_account

# Bước 1: Đường dẫn thư mục chứa các tệp CSV
csv_folder_path = '/Users/nguyentienhuy/Documents/fsds/BI/datawarehouse/'
print(os.listdir(csv_folder_path))
# Out:
# ['DimOrganization.csv', 'DimSalesReason.csv', 'DimGeography.csv', '.DS_Store', 'FactResellerSales.csv', 'DimProductCategory.csv', 'DimSalesTerritory.csv', 'DimReseller.csv', 'DimProductSubcategory.csv', 'DimDate.csv', 'FactInternetSales.csv', 'FactInternetSalesReason.csv', 'DimEmployeeSalesTerritory.csv', 'DimProduct.csv', 'DimEmployee.csv', 'DimCustomer.csv', 'DimPromotion.csv']
